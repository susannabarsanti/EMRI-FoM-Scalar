# %%
import numpy as np
import h5py

path = "/home/people/sbarsanti/scratch/EMRI-FoM-Scalar/pipeline/scalar_results/massless_montecarlo/M1e6mu50a099z05dt10T45/inference.h5"
with h5py.File(path, "r") as f:
    # reading parameters' names
    names = f["circular/param_names"][...]
    names = np.array([n.decode() if isinstance(n, (bytes, np.bytes_)) else str(n) for n in names])

    # Lambda index 
    idx = int(np.where(names == "Lambda")[0][0])

    # array (1000,) of sigma_Lambda
    sigma_lambda = f["circular/source_measurement_precision"][...][:, idx]

# median and 68% interval
q16, q50, q84 = np.percentile(sigma_lambda, [16, 50, 84])

print(f"Lambda (source frame):")
print(f"median sigma = {q50:.6e}")
print(f"68% CI       = [{q16:.6e}, {q84:.6e}]")
print("sigma(A)  =", q50*50/(12*32),"+", (q84-q50)*50/(12*32), "-", (q50-q16)*50/(12*32) )
# Out:
# Lambda (source frame):
# median sigma = 4.205371e-05
# 68% CI       = [2.728505e-05, 6.690033e-05]
# sigma(A)  = 5.475743073044025e-06 + 3.235236775271668e-06 - 1.9230022962612007e-06

# %%
path = "/home/people/sbarsanti/scratch/EMRI-FoM-Scalar/pipeline/scalar_results/massless_montecarlo/M1e5mu10a099z025dt10T45/inference.h5"
with h5py.File(path, "r") as f:
    # reading parameters' names
    names = f["circular/param_names"][...]
    names = np.array([n.decode() if isinstance(n, (bytes, np.bytes_)) else str(n) for n in names])

    # Lambda index 
    idx = int(np.where(names == "Lambda")[0][0])

    # array (1000,) of sigma_Lambda
    sigma_lambda = f["circular/source_measurement_precision"][...][:, idx]

# median and 68% interval
q16, q50, q84 = np.percentile(sigma_lambda, [16, 50, 84])

print(f"Lambda (source frame):")
print(f"median sigma = {q50:.6e}")
print(f"68% CI       = [{q16:.6e}, {q84:.6e}]")

print("sigma(A)  =", q50*50/(12*32))
print("sigma(A)  =", q50*50/(12*32),"+", (q84-q50)*50/(12*32), "-", (q50-q16)*50/(12*32) )
# Out:
# Lambda (source frame):
# median sigma = 1.223556e-05
# 68% CI       = [7.970306e-06, 1.873592e-05]
# sigma(A)  = 1.5931718658440145e-06
# sigma(A)  = 1.5931718658440145e-06 + 8.46401399190586e-07 - 5.553716598628641e-07

# %%
path = "/home/people/sbarsanti/scratch/EMRI-FoM-Scalar/pipeline/scalar_results/massless_montecarlo/M1e6mu100a099z05dt10T45/inference.h5"
with h5py.File(path, "r") as f:
    # reading parameters' names
    names = f["circular/param_names"][...]
    names = np.array([n.decode() if isinstance(n, (bytes, np.bytes_)) else str(n) for n in names])

    # Lambda index
    idx = int(np.where(names == "Lambda")[0][0])

    # array (1000,) of sigma_Lambda
    sigma_lambda = f["circular/source_measurement_precision"][...][:, idx]

# median and 68% interval 
q16, q50, q84 = np.percentile(sigma_lambda, [16, 50, 84])

print(f"Lambda (source frame):")
print(f"median sigma = {q50:.6e}")
print(f"68% CI       = [{q16:.6e}, {q84:.6e}]")

print("sigma(A)  =", q50*50/(12*32))
print("sigma(A)  =", q50*50/(12*32),"+", (q84-q50)*50/(12*32), "-", (q50-q16)*50/(12*32) )
# Out:
# Lambda (source frame):
# median sigma = 4.278505e-05
# 68% CI       = [2.736430e-05, 6.770123e-05]
# sigma(A)  = 5.570970035462081e-06
# sigma(A)  = 5.570970035462081e-06 + 3.2442941722323204e-06 - 2.0079105329474864e-06

# %%
path = "/home/people/sbarsanti/scratch/EMRI-FoM-Scalar/pipeline/scalar_results/massless_montecarlo/M1e5mu10a099z025dt3T45/inference.h5"
with h5py.File(path, "r") as f:
    # reading parameters' names
    names = f["circular/param_names"][...]
    names = np.array([n.decode() if isinstance(n, (bytes, np.bytes_)) else str(n) for n in names])

    # Lambda index
    idx = int(np.where(names == "Lambda")[0][0])

    # array (1000,) of sigma_Lambda
    sigma_lambda = f["circular/source_measurement_precision"][...][:, idx]

# median and 68% interval
q16, q50, q84 = np.percentile(sigma_lambda, [16, 50, 84])

print(f"Lambda (source frame):")
print(f"median sigma = {q50:.6e}")
print(f"68% CI       = [{q16:.6e}, {q84:.6e}]")

print("sigma(A)  =", q50*50/(12*32))
print("sigma(A)  =", q50*50/(12*32),"+", (q84-q50)*50/(12*32), "-", (q50-q16)*50/(12*32) )
# Out:
# Lambda (source frame):
# median sigma = 1.217404e-05
# 68% CI       = [7.932299e-06, 1.864487e-05]
# sigma(A)  = 1.5851618250033367e-06
# sigma(A)  = 1.5851618250033367e-06 + 8.425549730706164e-07 - 5.52310453436434e-07

# %%
path = "/home/people/sbarsanti/scratch/EMRI-FoM-Scalar/pipeline/scalar_results/massless_montecarlo/M1e6mu100a099z05dt10T45derorder8/inference.h5"
with h5py.File(path, "r") as f:
    # reading parameters' names
    names = f["circular/param_names"][...]
    names = np.array([n.decode() if isinstance(n, (bytes, np.bytes_)) else str(n) for n in names])

    # Lambda index
    idx = int(np.where(names == "Lambda")[0][0])

    # array (1000,) of sigma_Lambda
    sigma_lambda = f["circular/source_measurement_precision"][...][:, idx]

# median and 68% interval 
q16, q50, q84 = np.percentile(sigma_lambda, [16, 50, 84])

print(f"Lambda (source frame):")
print(f"median sigma = {q50:.6e}")
print(f"68% CI       = [{q16:.6e}, {q84:.6e}]")

print("sigma(A)  =", q50*50/(12*32))
print("sigma(A)  =", q50*50/(12*32),"+", (q84-q50)*50/(12*32), "-", (q50-q16)*50/(12*32) )
# Out:
# Lambda (source frame):
# median sigma = 3.477367e-05
# 68% CI       = [2.223737e-05, 5.458120e-05]
# sigma(A)  = 4.527821927457583e-06
# sigma(A)  = 4.527821927457583e-06 + 2.579105061099306e-06 - 1.6323304632041081e-06
